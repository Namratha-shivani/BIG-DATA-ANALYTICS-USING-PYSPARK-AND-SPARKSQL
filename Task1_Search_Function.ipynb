# %%
 import pandas as pd
 import numpy as np

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz
# !tar xf spark-3.2.0-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "spark-3.2.0-bin-hadoop3.2"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>

# %%
# reading stopwords
stopwords = sc.textFile('/content/stopwords.txt')

# %%
stopwords_list = stopwords.collect()

# %%
# Read all file names in the folder

# %%
path = '/content/'

# %%
file_list = os.listdir(path)

# %%
for i in file_list:
  if '.txt.txt' not in i:
    file_list.remove(i)

# %%
file_list.sort()

# %%
# Function to read all the text files simultaneously and create a dictionary
# Version with lambda function

def word_dict_lambda(path,file_list,stopwords_list):
  dict_words = {}
  for i in file_list:
    file_num = i.split('.')[0]
    file_read = sc.textFile(path+i)
    file_lower = file_read.flatMap(lambda x:x.lower().split())
    file_filter = file_lower.filter(lambda x:x not in stopwords_list)
    file_map = file_filter.map(lambda x:(x,1))
    file_reduce = file_map.reduceByKey(lambda x,y:x+y)
    reduce_list=file_reduce.collect()
    for i in reduce_list:
      if i[0] not in dict_words:
        dict_words[i[0]] = [(file_num,i[1])]
      else:
        dict_words[i[0]].append((file_num,i[1]))

  return dict_words


# Version with without lambda function

def word_dict_nolambda(path,file_list,stopwords_list):
  def lower_split(x):
    return x.lower().split()
  def filter_words(x):
    if x not in stopwords_list:
      return x
  def mapping(x):
    return (x,1)
  def frequency(x,y):
    return x+y

  dict_words = {}
  for i in file_list:
    file_num = i.split('.')[0]
    file_read = sc.textFile(path+i)
    file_lower = file_read.flatMap(lower_split)
    file_filter = file_lower.filter(filter_words)
    file_map = file_filter.map(mapping)
    file_reduce = file_map.reduceByKey(frequency)
    reduce_list=file_reduce.collect()
    for i in reduce_list:
      if i[0] not in dict_words:
        dict_words[i[0]] = [(file_num,i[1])]
      else:
        dict_words[i[0]].append((file_num,i[1]))

  return dict_words

# %%
dict_words = word_dict_lambda(path, file_list, stopwords_list)

# %%
dict_words
# Out:
# {'10': [('01', 1), ('08', 1), ('20', 1)],
#  'days,': [('01', 1)],
#  "nasa's": [('01', 1)],
#  'cassini': [('01', 2), ('09', 3)],
#  'step': [('01', 1), ('06', 1)],
#  'months-long': [('01', 1)],
#  'rings': [('01', 1)],
#  'scientists': [('01', 1), ('04', 1), ('14', 1)],
#  'unprecedented': [('01', 1)],
#  'sixth': [('01', 1)],
#  'sun.': [('01', 1)],
#  'end': [('01', 2), ('06', 1), ('10', 1)],
#  'mission': [('01', 1)],
#  'opened': [('01', 1)],
#  'eyes': [('01', 1)],
#  'two': [('01', 1)],
#  'worlds': [('01', 1)],
#  'home': [('01', 1), ('10', 1), ('16', 1)],
#  'alien': [('01', 1)],
#  'moons': [('01', 1), ('09', 1)],
#  'titan': [('01', 1)],
#  'really': [('01', 1)],
#  'era.': [('01', 1)],
#  'fans': [('01', 1)],
#  'devastated.': [('01', 1)],
#  'spacecraft': [('01', 1)],
#  'will': [('01', 1),
#   ('02', 1),
#   ('03', 2),
#   ('07', 1),
#   ('08', 1),
#   ('14', 2),
#   ('16', 1),
#   ('19', 1),
#   ('20', 1)],
#  'nose-dive': [('01', 1)],
#  'saturn': [('01', 2), ('09', 1)],
#  'burn': [('01', 1)],
#  "planet's": [('01', 1), ('09', 1)],
#  'atmosphere.': [('01', 1)],
#  'final,': [('01', 1)],
#  'suicidal': [('01', 1)],
#  'dance': [('01', 1)],
#  "saturn's": [('01', 1), ('09', 1)],
#  'given': [('01', 1), ('07', 1)],
#  'view': [('01', 1), ('05', 1)],
#  'planet': [('01', 1)],
#  'also': [('01', 1), ('09', 1), ('14', 1)],
#  'revolutionized': [('01', 1)],
#  'understanding': [('01', 1)],
#  'life': [('01', 1)],
#  '-': [('01', 1), ('14', 2)],
#  'enceladus.': [('01', 1)],
#  'microsoft': [('02', 4), ('03', 1), ('19', 4)],
#  'strongly': [('02', 2), ('19', 2)],
#  "administration's": [('02', 1), ('10', 2), ('19', 1)],
#  'decision': [('02', 1), ('06', 2), ('10', 2), ('19', 1)],
#  'tuesday': [('02', 1), ('07', 1), ('17', 2), ('19', 1)],
#  'move': [('02', 1), ('07', 1), ('10', 1), ('19', 1), ('20', 2)],
#  'toward': [('02', 1), ('19', 1)],
#  'replacing': [('02', 1), ('19', 1)],
#  'months.': [('02', 1), ('19', 1)],
#  'pushing': [('02', 1), ('13', 1), ('19', 1)],
#  'congress': [('02', 1), ('06', 1), ('10', 1), ('19', 1)],
#  'act': [('02', 1), ('19', 1)],
#  'on,"': [('02', 1), ('19', 1)],
#  'chief': [('02', 1), ('19', 1)],
#  'legal': [('02', 1), ('10', 1), ('19', 1)],
#  'officer': [('02', 1), ('19', 1)],
#  'smith': [('02', 5), ('19', 5)],
#  'said': [('02', 1),
#   ('03', 2),
#   ('06', 1),
#   ('07', 1),
#   ('08', 1),
#   ('10', 1),
#   ('14', 1),
#   ('19', 1)],
#  'npr.': [('02', 1), ('19', 1)],
#  'put': [('02', 1), ('15', 1), ('19', 1)],
#  'ground.': [('02', 1), ('19', 1)],
#  'tax': [('02', 1), ('19', 1)],
#  'reform': [('02', 1), ('19', 1)],
#  'bill,"': [('02', 1), ('19', 1)],
#  'entire': [('02', 1), ('18', 1), ('19', 1)],
#  'business': [('02', 1), ('19', 1)],
#  'community': [('02', 1), ('19', 1)],
#  'cares': [('02', 1), ('19', 1)],
#  'needs': [('02', 1), ('06', 1), ('19', 1)],
#  'settled': [('02', 1), ('19', 1)],
#  'added': [('02', 1), ('19', 1)],
#  'dreamers:': [('02', 1), ('19', 1)],
#  '"[the': [('02', 1), ('19', 1)],
#  "government's]": [('02', 1), ('19', 1)],
#  'go': [('02', 1), ('19', 1)],
#  'us': [('02', 1), ('06', 2), ('12', 1), ('19', 1)],
#  'latest': [('02', 1), ('19', 1)],
#  'speak': [('02', 1), ('19', 1)],
#  'similar': [('02', 1), ('19', 1)],
#  'comments': [('02', 1), ('19', 1)],
#  'public': [('02', 1), ('16', 1), ('19', 1)],
#  'responded': [('02', 1), ('19', 1)],
#  'trump': [('02', 1), ('10', 1), ('19', 1)],
#  'rescinding': [('02', 1), ('19', 1)],
#  'daca': [('02', 1), ('06', 1), ('10', 1), ('19', 1)],
#  'within': [('02', 1), ('19', 1)],
#  'six': [('02', 1), ('19', 1)],
#  '"there': [('02', 1), ('19', 1)],
#  'nothing': [('02', 1), ('06', 1), ('19', 1)],
#  'president': [('02', 1), ('06', 1), ('10', 2), ('19', 1)],
#  'brad': [('02', 1), ('19', 1)],
#  'interview': [('02', 1), ('05', 1), ('19', 1)],
#  '"we': [('02', 1), ('03', 1), ('19', 1)],
#  'stake': [('02', 1), ('19', 1)],
#  'care': [('02', 1), ('19', 1)],
#  'said,': [('02', 1), ('05', 1), ('19', 1)],
#  'noting': [('02', 1), ('19', 1)],
#  'one': [('02', 1),
#   ('04', 1),
#   ('05', 2),
#   ('08', 3),
#   ('09', 1),
#   ('15', 1),
#   ('17', 1),
#   ('18', 1),
#   ('19', 1),
#   ('20', 1)],
#  'first.': [('02', 1), ('19', 1)],
#  'easy': [('02', 1), ('19', 1)],
#  'government': [('02', 1), ('19', 1)],
#  'deport': [('02', 1), ('19', 1)],
#  'employees': [('02', 1), ('19', 1)],
#  'going': [('02', 1), ('08', 1), ('11', 2), ('19', 1)],
#  'get': [('02', 1), ('18', 1), ('19', 1)],
#  'person,"': [('02', 1), ('19', 1)],
#  'said.': [('02', 1), ('03', 1), ('14', 1), ('19', 1)],
#  'tech': [('02', 1), ('03', 1), ('19', 1)],
#  'company': [('02', 1), ('19', 1)],
#  'move.': [('02', 1), ('19', 1)],
#  'made': [('02', 1), ('19', 1)],
#  'letter.': [('02', 1), ('19', 1)],
#  'putin': [('03', 1)],
#  'development': [('03', 2)],
#  'ai': [('03', 5)],
#  '"colossal': [('03', 1)],
#  'leader': [('03', 1)],
#  'sphere': [('03', 1)],
#  'become': [('03', 2)],
#  'ruler': [('03', 1)],
#  'meeting': [('03', 1)],
#  'united': [('03', 1), ('10', 2)],
#  'considered': [('03', 1)],
#  'nation': [('03', 1)],
#  'leading': [('03', 1)],
#  'charge': [('03', 1)],
#  'towards': [('03', 1), ('14', 1)],
#  'currently,': [('03', 1)],
#  'like': [('03', 1)],
#  'google': [('03', 1)],
#  'large': [('03', 1)],
#  'amounts': [('03', 1)],
#  'cash': [('03', 1)],
#  'research': [('03', 1), ('14', 1), ('16', 1)],
#  'last': [('03', 1), ('13', 1), ('16', 1)],
#  'goldman': [('03', 1)],
#  'sachs': [('03', 1)],
#  'believe': [('03', 1)],
#  'technology': [('03', 1)],
#  'priority': [('03', 1)],
#  'national/regional': [('03', 1)],
#  'policy': [('03', 1)],
#  'support': [('03', 1)],
#  'follow,"': [('03', 1)],
#  'bank': [('03', 1), ('13', 1), ('20', 1)],
#  'raises': [('03', 1), ('16', 1)],
#  'opportunities"': [('03', 1)],
#  '"threats': [('03', 1)],
#  'difficult': [('03', 1), ('08', 1)],
#  'predict."': [('03', 1)],
#  '"whoever': [('03', 1)],
#  'becomes': [('03', 1)],
#  'world,"': [('03', 1)],
#  'students': [('03', 1)],
#  'friday.': [('03', 1)],
#  'states': [('03', 1), ('10', 1)],
#  'generally': [('03', 1), ('07', 1)],
#  'giants': [('03', 1)],
#  'pouring': [('03', 1)],
#  'projects.': [('03', 1)],
#  'week,': [('03', 1), ('20', 1)],
#  'report': [('03', 1), ('20', 1)],
#  'found': [('03', 1), ('14', 1), ('20', 2)],
#  'china': [('03', 1)],
#  'capability': [('03', 1)],
#  'catch': [('03', 1)],
#  'u.s.': [('03', 1), ('07', 1), ('13', 2), ('15', 2), ('17', 2)],
#  "government's": [('03', 1)],
#  'agenda,': [('03', 1)],
#  'expect': [('03', 1), ('08', 1)],
#  'funding': [('03', 1)],
#  'investment': [('03', 1)],
#  'provides': [('04', 1)],
#  'alternative': [('04', 1)],
#  'dairy': [('04', 1)],
#  'brewed': [('04', 1)],
#  'lab.': [('04', 1)],
#  'lab': [('04', 1)],
#  'heart': [('04', 1), ('14', 2)],
#  'financial': [('04', 1), ('18', 1)],
#  'working': [('04', 1)],
#  'things': [('04', 1), ('05', 1)],
#  'run': [('04', 1)],
#  'bio-technology': [('04', 1)],
#  'accelerator': [('04', 1)],
#  'indiebio,': [('04', 1)],
#  'funded': [('04', 1)],
#  '68': [('04', 1)],
#  'early-stage': [('04', 1)],
#  'start-ups.': [('04', 1)],
#  'biggest': [('04', 1), ('08', 2)],
#  'raised': [('04', 1)],
#  '$17': [('04', 1)],
#  'past': [('04', 1), ('08', 1)],
#  'month': [('04', 1), ('13', 1)],
#  '"clean"': [('04', 1)],
#  'bioreactor-brewed': [('04', 1)],
#  'slew': [('04', 1)],
#  'gates': [('04', 1)],
#  'branson,': [('04', 1)],
#  "musk's": [('04', 1)],
#  'brother': [('04', 1)],
#  'kimball': [('04', 1)],
#  'electric': [('04', 1)],
#  'ceo': [('04', 1)],
#  'welch.': [('04', 1)],
#  'meat': [('04', 2)],
#  'require': [('04', 1)],
#  'slaughter': [('04', 1)],
#  'animals.': [('04', 1)],
#  'fashion': [('04', 1)],
#  'eco-friendly': [('04', 1)],
#  'leather.': [('04', 1)],
#  'products': [('04', 1)],
#  'lactose-free': [('04', 1)],
#  'san': [('04', 1)],
#  'franciscans': [('04', 1)],
#  'aware': [('04', 1)],
#  'district': [('04', 1)],
#  'entrepreneurs': [('04', 1)],
#  'more.': [('04', 1), ('11', 1)],
#  'lab,': [('04', 1)],
#  'program': [('04', 1), ('10', 1)],
#  'called': [('04', 1)],
#  'successes,': [('04', 1)],
#  'memphis': [('04', 2)],
#  'meats,': [('04', 1)],
#  'million': [('04', 1)],
#  'high-profile': [('04', 1)],
#  'investors,': [('04', 1)],
#  'including': [('04', 1)],
#  'billionaires': [('04', 1)],
#  'bill': [('04', 1)],
#  'richard': [('04', 1)],
#  'elon': [('04', 1)],
#  'general': [('04', 1), ('05', 1), ('06', 1)],
#  'jack': [('04', 1)],
#  'indiebio': [('04', 1)],
#  "meat's": [('04', 1)],
#  'first': [('04', 1), ('05', 1), ('09', 3), ('14', 1), ('15', 3)],
#  'investor.': [('04', 1)],
#  'just': [('05', 2), ('08', 1), ('15', 1), ('20', 1)],
#  'say': [('05', 1), ('07', 1), ('13', 2)],
#  'equity': [('05', 1)],
#  'incomplete.': [('05', 1)],
#  'especially': [('05', 1)],
#  'blockchain': [('05', 1)],
#  'use': [('05', 1), ('10', 1), ('11', 1), ('12', 1)],
#  'proxy': [('05', 1)],
#  'do,': [('05', 1)],
#  'interesting': [('05', 1)],
#  'networks.': [('05', 1)],
#  'point': [('05', 1)],
#  'making': [('05', 1), ('14', 1)],
#  'distinction,': [('05', 1)],
#  'mind:': [('05', 1)],
#  'work': [('05', 1), ('16', 1)],
#  'ensure': [('05', 1)],
#  'tokens': [('05', 1)],
#  'blockchain-based': [('05', 1)],
#  'assets': [('05', 1), ('12', 1)],
#  'markets': [('05', 1)],
#  '(like': [('05', 1)],
#  'houses)': [('05', 1)],
#  'equities,': [('05', 1)],
#  'happening': [('05', 1)],
#  'unparalleled.': [('05', 1)],
#  'bunch': [('05', 1)],
#  'quite': [('05', 1)],
#  'turn': [('05', 1)],
#  'internet': [('05', 2)],
#  'market.': [('05', 1)],
#  'anyone': [('05', 1)],
#  'connection': [('05', 1)],
#  'purchase': [('05', 1)],
#  'shapeshift.io': [('05', 1)],
#  'so,': [('05', 1)],
#  'all,': [('05', 1)],
#  'want': [('05', 2), ('06', 1)],
#  'analogy': [('05', 1)],
#  'token': [('05', 2)],
#  'u.s.,': [('05', 1)],
#  'compliant': [('05', 1)],
#  'regulations': [('05', 1)],
#  'need': [('05', 1)],
#  'utility': [('05', 1)],
#  'component': [('05', 1)],
#  'equities.': [('05', 2)],
#  'hard': [('05', 1)],
#  'many': [('05', 1), ('07', 1), ('12', 1), ('16', 1)],
#  'can': [('05', 2), ('06', 1), ('12', 1), ('13', 1), ('18', 3)],
#  'tokenized': [('05', 1)],
#  'stickler': [('05', 1)],
#  'every': [('05', 1)],
#  'important': [('05', 1), ('12', 1), ('20', 1)],
#  'keep': [('05', 1), ('08', 1)],
#  'lawyers': [('05', 1)],
#  'relative': [('05', 1)],
#  'existing': [('05', 1)],
#  'secondary': [('05', 2)],
#  'either': [('05', 1)],
#  'property': [('05', 1)],
#  'scale': [('05', 1)],
#  'market': [('05', 1), ('18', 1)],
#  'thing': [('05', 1)],
#  'small': [('05', 1)],
#  'markets;': [('05', 1)],
#  'another': [('05', 1)],
#  'token.': [('05', 1)],
#  'see': [('05', 1), ('18', 1)],
#  'great': [('05', 1)],
#  'example': [('05', 1)],
#  'this.': [('05', 1)],
#  'decried': [('06', 1)],
#  '800,000': [('06', 1), ('10', 1)],
#  'america': [('06', 1)],
#  '"wrong,"': [('06', 1)],
#  'rare': [('06', 1)],
#  'political': [('06', 1), ('10', 1), ('13', 1), ('20', 1)],
#  'stage,': [('06', 1)],
#  'used': [('06', 1), ('11', 2)],
#  'facebook': [('06', 1), ('10', 1)],
#  'call': [('06', 1)],
#  '"to': [('06', 1)],
#  'young': [('06', 1), ('10', 1)],
#  'wrong.': [('06', 1)],
#  'self-defeating': [('06', 1)],
#  'start': [('06', 1)],
#  'new': [('06', 1), ('11', 3), ('20', 2)],
#  'businesses,': [('06', 1)],
#  'staff': [('06', 1), ('11', 2)],
#  'labs,': [('06', 1)],
#  'serve': [('06', 1)],
#  'military,': [('06', 1)],
#  'country': [('06', 1), ('10', 2)],
#  'love.': [('06', 1)],
#  'scrap': [('06', 1)],
#  'country.': [('06', 2)],
#  'gathered': [('06', 1)],
#  'house': [('06', 1)],
#  'attorney': [('06', 1)],
#  'jeff': [('06', 1)],
#  'move,': [('06', 1)],
#  'lawful': [('06', 1)],
#  'immigration': [('06', 1)],
#  'interest': [('06', 1), ('12', 1)],
#  'admitted': [('06', 1)],
#  'former': [('06', 1), ('10', 2)],
#  'barack': [('06', 1), ('10', 1)],
#  'obama': [('06', 2), ('10', 3)],
#  "successor's": [('06', 1)],
#  'amnesty': [('06', 2)],
#  'people': [('06', 2), ('16', 1)],
#  'brought': [('06', 1), ('10', 2)],
#  'illegally': [('06', 1)],
#  'children,': [('06', 1)],
#  'describing': [('06', 1)],
#  '"self-defeating"': [('06', 1), ('10', 1)],
#  '"cruel."': [('06', 1)],
#  're-entry': [('06', 1)],
#  'onto': [('06', 1)],
#  'post': [('06', 1), ('10', 1)],
#  'slam': [('06', 1), ('15', 2)],
#  "trump's": [('06', 2)],
#  'in.': [('06', 1), ('20', 1)],
#  'target': [('06', 1)],
#  'wrong': [('06', 1)],
#  '--': [('06', 2)],
#  'done': [('06', 1)],
#  'otherwise': [('06', 1)],
#  'contribute': [('06', 1)],
#  'cruel,"': [('06', 1)],
#  'wrote.': [('06', 1), ('10', 1)],
#  'donald': [('06', 1)],
#  'announcement': [('06', 1)],
#  'programme': [('06', 1)],
#  'met': [('06', 1)],
#  'protests': [('06', 1)],
#  'across': [('06', 1), ('17', 1)],
#  'hundreds': [('06', 1)],
#  'outside': [('06', 1)],
#  'white': [('06', 1), ('10', 1)],
#  'protest.': [('06', 1)],
#  'sessions,': [('06', 1)],
#  'defending': [('06', 1)],
#  'system': [('06', 1), ('20', 1)],
#  'serves': [('06', 1)],
#  'national': [('06', 1), ('17', 1)],
#  'everyone': [('06', 1)],
#  'due': [('07', 1)],
#  'strategist': [('07', 1)],
#  'larry': [('07', 1)],
#  'mcdonald': [('07', 3)],
#  'tuesday,': [('07', 1), ('13', 1)],
#  'treasury': [('07', 1)],
#  'yield': [('07', 1)],
#  '2.07': [('07', 1)],
#  '�': [('07', 1), ('08', 2), ('12', 2), ('13', 1), ('18', 1), ('20', 1)],
#  '2016.': [('07', 1)],
#  'economy': [('07', 1)],
#  'continues': [('07', 1), ('12', 1)],
#  'reflects': [('07', 1)],
#  'global': [('07', 1)],
#  'risk': [('07', 1)],
#  'nation."': [('07', 1)],
#  'view."': [('07', 1)],
#  'reflect': [('07', 1)],
#  'strength': [('07', 1)],
#  'perceived': [('07', 1)],
#  'chance': [('07', 1)],
#  'money': [('07', 1), ('12', 1), ('15', 1), ('18', 5), ('20', 1)],
#  'higher': [('07', 2)],
#  'rate': [('07', 1)],
#  'loftier': [('07', 1)],
#  'be.': [('07', 1)],
#  'based': [('07', 1)],
#  'metric,': [('07', 1)],
#  'low': [('07', 1)],
#  'points': [('07', 1)],
#  'institute': [('07', 1)],
#  'management': [('07', 1), ('12', 1)],
#  'manufacturing': [('07', 1)],
#  'index,': [('07', 1)],
#  'came': [('07', 1), ('15', 1), ('20', 1)],
#  'then,': [('07', 1)],
#  '"1.5': [('07', 1)],
#  'now,"': [('07', 1)],
#  'bond': [('07', 2)],
#  'yields': [('07', 7)],
#  'rise': [('07', 1)],
#  'big': [('07', 1)],
#  'way,': [('07', 1)],
#  'according': [('07', 1),
#   ('08', 1),
#   ('11', 2),
#   ('12', 1),
#   ('13', 1),
#   ('14', 1),
#   ('18', 1)],
#  'acg': [('07', 1)],
#  'analytics.': [('07', 1)],
#  '10-year': [('07', 1)],
#  'fell': [('07', 1)],
#  'percent': [('07', 2), ('08', 1), ('12', 1), ('13', 1), ('20', 1)],
#  'lowest': [('07', 1)],
#  'level': [('07', 2), ('13', 1)],
#  'since': [('07', 2), ('15', 1), ('20', 1)],
#  'november': [('07', 1)],
#  'firm': [('07', 1), ('08', 1)],
#  'footing,': [('07', 1)],
#  'jitters.': [('07', 1)],
#  '"geopolitical': [('07', 1)],
#  'coming': [('07', 1), ('14', 1)],
#  'north': [('07', 1), ('13', 1)],
#  'korea': [('07', 1)],
#  'driving': [('07', 1)],
#  'much,': [('07', 1)],
#  'much': [('07', 1), ('13', 1), ('16', 1)],
#  'lower,"': [('07', 1)],
#  "cnbc's": [('07', 1), ('08', 1)],
#  '"trading': [('07', 1)],
#  'driven': [('07', 1)],
#  '"unsustainably': [('07', 1)],
#  'lower,': [('07', 1)],
#  'economy.': [('07', 1)],
#  'greater': [('07', 1)],
#  'earning': [('07', 1)],
#  'assets,': [('07', 1)],
#  'expected': [('07', 1), ('08', 1), ('17', 1)],
#  'inflation,': [('07', 1)],
#  'tend': [('07', 1)],
#  'strikingly': [('07', 1)],
#  'indeed.': [('07', 1)],
#  "friday's": [('07', 1)],
#  'reading': [('07', 1)],
#  'supply': [('07', 1)],
#  'highest': [('07', 1)],
#  '2011.': [('07', 1)],
#  'back': [('07', 1), ('20', 1)],
#  'noted.': [('07', 1)],
#  'cycle': [('08', 2)],
#  'yet': [('08', 1)],
#  'mean': [('08', 1)],
#  'soaring,': [('08', 1)],
#  "company's": [('08', 1)],
#  'followers.': [('08', 1)],
#  'shares': [('08', 1)],
#  'three': [('08', 2), ('15', 1)],
#  'months,': [('08', 1)],
#  'gene': [('08', 1)],
#  'told': [('08', 1), ('14', 1)],
#  '"power': [('08', 1)],
#  'lunch"': [('08', 1)],
#  'tuesday.': [('08', 1)],
#  '"the': [('08', 1), ('20', 1)],
#  'four': [('08', 1), ('09', 1)],
#  'years': [('08', 2), ('09', 1), ('14', 2), ('15', 1), ('16', 1), ('18', 2)],
#  'look': [('08', 1)],
#  'months': [('08', 1), ('09', 1), ('20', 1)],
#  'after,"': [('08', 1)],
#  'munster,': [('08', 1)],
#  'covered': [('08', 1)],
#  'analyst': [('08', 1), ('20', 1)],
#  'becoming': [('08', 1)],
#  'loup': [('08', 1)],
#  'ventures.': [('08', 1)],
#  '"but': [('08', 1)],
#  'run-ups': [('08', 1)],
#  'suggest,': [('08', 1)],
#  'typically,': [('08', 1)],
#  "apple's": [('08', 1)],
#  'next': [('08', 2), ('15', 1)],
#  'iphone': [('08', 1)],
#  'necessarily': [('08', 1)],
#  'stock': [('08', 1), ('18', 1)],
#  'well-known': [('08', 1), ('18', 1)],
#  'pullback': [('08', 1)],
#  'apple': [('08', 2), ('11', 2)],
#  'munster': [('08', 1)],
#  'trading': [('08', 1), ('18', 1)],
#  'history': [('08', 1), ('18', 1)],
#  'little': [('08', 1)],
#  'bit': [('08', 1)],
#  'happens': [('08', 1)],
#  "product's": [('08', 1)],
#  'announced': [('08', 1)],
#  'wall': [('08', 1), ('18', 2)],
#  'street': [('08', 1), ('18', 1)],
#  'managing': [('08', 1), ('18', 1)],
#  'partner': [('08', 1)],
#  'venture': [('08', 1)],
#  'capital': [('08', 1), ('13', 1)],
#  'product': [('08', 1), ('18', 1)],
#  'tail-off.': [('08', 1)],
#  'thing."': [('08', 1)],
#  'journey': [('09', 1)],
#  'earth': [('09', 1)],
#  '1997.': [('09', 1)],
#  'named': [('09', 2)],
#  'cassini,': [('09', 2)],
#  'gap': [('09', 1)],
#  'carried': [('09', 1)],
#  'single': [('09', 1)],
#  'lander,': [('09', 1)],
#  'european': [('09', 1)],
#  'space': [('09', 1)],
#  'agency': [('09', 1)],
#  'dutch': [('09', 1)],
#  'spotted': [('09', 1)],
#  'orbit': [('09', 2)],
#  'seven': [('09', 1)],
#  'launch,': [('09', 1)],
#  'july': [('09', 1)],
#  '2004.': [('09', 1)],
#  'several': [('09', 1)],
#  'touched': [('09', 1)],
#  "titan's": [('09', 1)],
#  'lakes': [('09', 1)],
#  'methane.': [('09', 1)],
#  "humankind's": [('09', 1)],
#  'landing': [('09', 2)],
#  'kind': [('09', 1), ('11', 1)],
#  'outer': [('09', 1)],
#  'meanwhile,': [('09', 1)],
#  'probe': [('09', 1)],
#  '(pioneer': [('09', 1)],
#  'voyager': [('09', 1)],
#  'by,': [('09', 1)],
#  '1979': [('09', 1)],
#  '1980,': [('09', 1)],
#  'respectively.)': [('09', 1)],
#  'launched': [('09', 1)],
#  'billion-mile': [('09', 1)],
#  'oct.': [('09', 1)],
#  '15,': [('09', 1)],
#  'astronomer': [('09', 1), ('14', 1)],
#  'giovanni': [('09', 1)],
#  'discovered': [('09', 1), ('14', 1)],
#  'rings.': [('09', 1)],
#  'passenger:': [('09', 1)],
#  'huygens': [('09', 3)],
#  'built': [('09', 1)],
#  'scientist': [('09', 1)],
#  'moon': [('09', 2)],
#  'titan.': [('09', 1)],
#  'arrived': [('09', 1), ('15', 1)],
#  'later,': [('09', 1)],
#  'split': [('09', 1)],
#  'shore': [('09', 1)],
#  'liquid': [('09', 1)],
#  'first-ever': [('09', 1)],
#  'own,': [('09', 1)],
#  'solar': [('09', 1)],
#  'system.': [('09', 1)],
#  'saturn.': [('09', 1)],
#  'simply': [('09', 1)],
#  'flown': [('09', 1)],
#  'sharply': [('10', 1)],
#  'slamming': [('10', 1)],
#  'unnecessary': [('10', 1)],
#  'decision.': [('10', 1)],
#  'page,': [('10', 1)],
#  'defended': [('10', 1)],
#  'shield': [('10', 1)],
#  'immigrants': [('10', 1)],
#  'children.': [('10', 1)],
#  'decided': [('10', 1)],
#  'individuals': [('10', 1)],
#  'know': [('10', 3), ('11', 1)],
#  'states,': [('10', 1)],
#  'failed': [('10', 1)],
#  'act.': [('10', 1)],
#  'sometimes': [('10', 1)],
#  'even': [('10', 2), ('13', 1), ('14', 1), ('18', 1)],
#  'infants.': [('10', 1)],
#  'may': [('10', 2), ('11', 1), ('20', 1)],
#  'language': [('10', 1)],
#  'idea': [('10', 1)],
#  "driver's": [('10', 1)],
#  'criticized': [('10', 1)],
#  'protects': [('10', 1)],
#  'undocumented': [('10', 3)],
#  'migrants': [('10', 1)],
#  'deportation,': [('10', 1)],
#  "house's": [('10', 1)],
#  '"cruel,"': [('10', 1)],
#  'legally': [('10', 1)],
#  '"well-established': [('10', 1)],
#  'principle': [('10', 1)],
#  'discretion"': [('10', 1)],
#  'protect': [('10', 1)],
#  '"they': [('10', 2)],
#  'parents,': [('10', 1)],
#  'besides': [('10', 2)],
#  'ours,"': [('10', 1)],
#  'english.': [('10', 1)],
#  'often': [('10', 1)],
#  'apply': [('10', 1)],
#  'job,': [('10', 1)],
#  'college,': [('10', 1)],
#  'license."': [('10', 1)],
#  'major': [('11', 1), ('16', 1)],
#  'league': [('11', 1)],
#  'confirmed': [('11', 1)],
#  'team': [('11', 1)],
#  'watch': [('11', 2)],
#  'steal': [('11', 2)],
#  'york': [('11', 3)],
#  'yankees,': [('11', 1)],
#  'times.': [('11', 1)],
#  'sorts': [('11', 1)],
#  'reasons,': [('11', 1)],
#  'typically': [('11', 1)],
#  'tell': [('11', 1)],
#  'players': [('11', 1)],
#  'bases,': [('11', 1)],
#  'throw': [('11', 2)],
#  'times,': [('11', 1)],
#  'caught': [('11', 1)],
#  '"a': [('11', 1)],
#  'training': [('11', 1), ('15', 1)],
#  'looking': [('11', 1)],
#  'players,': [('11', 1)],
#  'able': [('11', 1), ('18', 2)],
#  'type': [('11', 1)],
#  'pitch': [('11', 1)],
#  'pitcher': [('11', 1)],
#  'example,': [('11', 1)],
#  'batter.': [('11', 1)],
#  'baseball': [('11', 2)],
#  'boston': [('11', 2)],
#  'red': [('11', 3)],
#  'sox': [('11', 3)],
#  'hand': [('11', 2)],
#  'signals': [('11', 2)],
#  'teams': [('11', 1)],
#  'pitches': [('11', 1)],
#  'yankees': [('11', 1)],
#  'member': [('11', 2)],
#  'dugout': [('11', 1)],
#  'relaying': [('11', 1)],
#  'message': [('11', 1)],
#  'information': [('11', 2)],
#  'thrown."': [('11', 1)],
#  'fastball,': [('11', 1)],
#  'relayed': [('11', 1)],
#  'socially': [('12', 1)],
#  'responsible': [('12', 4)],
#  'ever.': [('12', 1)],
#  'following': [('12', 1)],
#  'around': [('12', 1), ('14', 1)],
#  'paris': [('12', 1)],
#  'climate': [('12', 1)],
#  'likely': [('12', 1), ('14', 1)],
#  'make': [('12', 1), ('18', 1)],
#  'positive': [('12', 1)],
#  'impact.': [('12', 1)],
#  'u.s.-domiciled': [('12', 1)],
#  'using': [('12', 1), ('14', 1)],
#  'sustainable,': [('12', 1)],
#  'trillion,': [('12', 2)],
#  '2014': [('12', 1)],
#  '2016': [('12', 1)],
#  'increase': [('12', 1)],
#  '33': [('12', 1)],
#  'sustainable': [('12', 2)],
#  'investment.': [('12', 1)],
#  'investment,': [('12', 1)],
#  'sri,': [('12', 1)],
#  'understand': [('12', 1), ('14', 1)],
#  'different': [('12', 1), ('16', 2)],
#  'them,': [('12', 1)],
#  'set': [('12', 1)],
#  'measurable': [('12', 1)],
#  'lasting': [('12', 1)],
#  'legacy.': [('12', 1)],
#  'investing': [('12', 1), ('18', 1)],
#  'attracting': [('12', 1)],
#  'dollars': [('12', 1)],
#  'fact,': [('12', 1)],
#  'recent': [('12', 1)],
#  'developments': [('12', 1)],
#  'agreement,': [('12', 1)],
#  'investors': [('12', 2), ('18', 1)],
#  'asking': [('12', 1)],
#  'total': [('12', 1), ('20', 1)],
#  'impact': [('12', 1)],
#  'strategies': [('12', 1)],
#  'grew': [('12', 1), ('15', 1)],
#  '$8.72': [('12', 1)],
#  '$6.57': [('12', 1)],
#  'study': [('12', 1), ('16', 1)],
#  'sif:': [('12', 1)],
#  'forum': [('12', 1)],
#  'grow,': [('12', 1)],
#  'evaluate': [('12', 1)],
#  'methods': [('12', 1)],
#  'available': [('12', 1)],
#  'goals': [('12', 1)],
#  'build': [('12', 1)],
#  'strategy': [('12', 1), ('20', 2)],
#  'leaving': [('12', 1)],
#  'yuan': [('13', 4)],
#  'year': [('13', 1)],
#  'now': [('13', 1), ('18', 1)],
#  "year's": [('13', 1)],
#  'losses': [('13', 1)],
#  'room': [('13', 1)],
#  'run.': [('13', 1)],
#  'dollar,': [('13', 1)],
#  'gains': [('13', 1)],
#  'data.': [('13', 1)],
#  "currency's": [('13', 1)],
#  'appreciation': [('13', 1)],
#  'quickened': [('13', 1)],
#  'marking': [('13', 1)],
#  'best': [('13', 1)],
#  '2017.': [('13', 1)],
#  'strengthened': [('13', 1)],
#  'expected,': [('13', 1)],
#  'trend.': [('13', 1)],
#  'asian': [('13', 1)],
#  'falling': [('13', 1)],
#  'rising': [('13', 1)],
#  'korea,': [('13', 1)],
#  'chinese': [('13', 1)],
#  'continued': [('13', 1), ('17', 1)],
#  'central': [('13', 1), ('20', 1)],
#  'pressure': [('13', 1)],
#  'controls': [('13', 1)],
#  'foreign': [('13', 1)],
#  'intervention.': [('13', 1)],
#  "china's": [('13', 1)],
#  'tear': [('13', 1)],
#  'recouped': [('13', 1)],
#  'analysts': [('13', 1), ('20', 1)],
#  'still': [('13', 1), ('18', 1)],
#  'strongest': [('13', 1)],
#  'changing': [('13', 1)],
#  'hands': [('13', 1)],
#  '6.5151': [('13', 1)],
#  '6': [('13', 1)],
#  'year,': [('13', 1)],
#  'reuters': [('13', 1)],
#  'pace': [('13', 1)],
#  'august,': [('13', 1)],
#  'faster': [('13', 1)],
#  'bucked': [('13', 1)],
#  'currencies': [('13', 1)],
#  'face': [('13', 1), ('15', 1)],
#  'tensions': [('13', 1)],
#  'actually': [('13', 1)],
#  'appreciating.': [('13', 1)],
#  'experts': [('13', 1)],
#  'succeeded': [('13', 1)],
#  'demonstrating': [('13', 1)],
#  'withstand': [('13', 1)],
#  'downward': [('13', 1)],
#  'currency': [('13', 1), ('20', 1)],
#  'tightening': [('13', 1)],
#  'exchange': [('13', 1)],
#  'huge': [('14', 1), ('18', 1)],
#  'blackhole': [('14', 2)],
#  'massive': [('14', 1)],
#  'sun': [('14', 1)],
#  'lurking': [('14', 1)],
#  'cloud': [('14', 3)],
#  'near': [('14', 1)],
#  'way.': [('14', 1)],
#  'way': [('14', 5), ('20', 2)],
#  'supermassive': [('14', 2)],
#  'sagittarius': [('14', 2)],
#  'a*': [('14', 2)],
#  'astronomers': [('14', 1)],
#  'university': [('14', 1)],
#  'japan': [('14', 1)],
#  'chile': [('14', 1)],
#  'movement': [('14', 1)],
#  'molecules': [('14', 1)],
#  '150': [('14', 1)],
#  'trillion': [('14', 2), ('20', 1)],
#  'wide,': [('14', 1)],
#  'pulled': [('14', 1)],
#  'immense': [('14', 1)],
#  'models,': [('14', 1)],
#  'hole': [('14', 4)],
#  'detected': [('14', 1)],
#  'waves': [('14', 1)],
#  'presence': [('14', 1)],
#  'hole.': [('14', 1)],
#  'tomoharu': [('14', 1)],
#  'oka,': [('14', 1)],
#  'university.': [('14', 1)],
#  'dwarf': [('14', 1)],
#  'cannibalised': [('14', 1)],
#  'formation': [('14', 1)],
#  'billions': [('14', 1)],
#  'ago,': [('14', 1)],
#  'mr': [('14', 2)],
#  'oka': [('14', 2)],
#  'it,': [('14', 1)],
#  'massive,': [('14', 1)],
#  'published': [('14', 1)],
#  '100,000': [('14', 1)],
#  'times': [('14', 1)],
#  'toxic': [('14', 1)],
#  'gas': [('14', 2)],
#  'milky': [('14', 6)],
#  'confirmed,': [('14', 1)],
#  'object': [('14', 2)],
#  'rank': [('14', 1)],
#  'second': [('14', 1), ('15', 1)],
#  'largest': [('14', 1)],
#  'located': [('14', 1)],
#  'centre': [('14', 3)],
#  'galaxy.': [('14', 1)],
#  'keio': [('14', 2)],
#  'alma': [('14', 1)],
#  'telescope': [('14', 1)],
#  'observing': [('14', 1)],
#  'gases.': [('14', 1)],
#  'elliptical': [('14', 1)],
#  'cloud,': [('14', 1)],
#  '200': [('14', 1)],
#  'light': [('14', 1)],
#  'kilometres': [('14', 2)],
#  'gravitational': [('14', 1)],
#  'forces.': [('14', 1)],
#  'cause,': [('14', 1)],
#  'computer': [('14', 1), ('16', 1)],
#  'black': [('14', 5), ('20', 1)],
#  '1.4': [('14', 1)],
#  'across.': [('14', 1)],
#  'radio': [('14', 1)],
#  'indicated': [('14', 1)],
#  '"this': [('14', 1)],
#  'detection': [('14', 1)],
#  'intermediate-mass': [('14', 1)],
#  'candidate': [('14', 1)],
#  'galaxy,"': [('14', 1)],
#  'newly-found': [('14', 1)],
#  'core': [('14', 1)],
#  'old': [('14', 1)],
#  'galaxy': [('14', 1)],
#  "'the": [('14', 1)],
#  "guardian'.": [('14', 1)],
#  'time,': [('14', 1)],
#  'drawn': [('14', 1)],
#  'sink': [('14', 1)],
#  'journal': [('14', 1)],
#  'nature': [('14', 1)],
#  'astronomy.�': [('14', 1)],
#  'suspension': [('15', 1)],
#  'use,': [('15', 1)],
#  'sharapova': [('15', 3)],
#  'open': [('15', 1), ('16', 1)],
#  'monday': [('15', 1)],
#  'night.': [('15', 1)],
#  '30-year-old': [('15', 1)],
#  'performance': [('15', 1)],
#  'arthur': [('15', 1)],
#  'stadium,': [('15', 1)],
#  'no.': [('15', 1)],
#  'seed': [('15', 1)],
#  'today,': [('15', 1)],
#  'round': [('15', 1)],
#  'decade': [('15', 1)],
#  'clinched': [('15', 1)],
#  'grand': [('15', 2)],
#  'championship.': [('15', 1)],
#  'defeated': [('15', 1)],
#  '2004': [('15', 1)],
#  'wimbledon': [('15', 1)],
#  'final.': [('15', 1)],
#  'titles,': [('15', 1)],
#  '�560,500,': [('15', 1)],
#  'teenager,': [('15', 1)],
#  'particularly': [('15', 1), ('16', 1)],
#  'athlete': [('15', 1)],
#  'dad': [('15', 2)],
#  'academy,': [('15', 1)],
#  'slept': [('15', 1)],
#  'couch': [('15', 1)],
#  '$250-a-month': [('15', 1)],
#  'apartment.': [('15', 1)],
#  'six-figure': [('15', 1)],
#  'check,': [('15', 1)],
#  'headed': [('15', 1)],
#  'tj': [('15', 1)],
#  'maxx.': [('15', 1)],
#  '15-month': [('15', 1)],
#  'drug': [('15', 1)],
#  'maria': [('15', 1)],
#  'returned': [('15', 1)],
#  'time': [('15', 1)],
#  'memorable': [('15', 1)],
#  'lights': [('15', 1)],
#  'ashe': [('15', 1)],
#  'downing': [('15', 1)],
#  '2': [('15', 1)],
#  'simona': [('15', 1)],
#  'halep.': [('15', 1)],
#  'timea': [('15', 1)],
#  'babos': [('15', 1)],
#  'major.': [('15', 1)],
#  'age': [('15', 2)],
#  '17,': [('15', 1)],
#  'serena': [('15', 1)],
#  'williams': [('15', 1)],
#  'five': [('15', 1)],
#  'sizable': [('15', 1)],
#  'paycheck:': [('15', 1)],
#  '$724,000.': [('15', 1)],
#  'lot': [('15', 1)],
#  'poor:': [('15', 1)],
#  'seven,': [('15', 1)],
#  'russian-born': [('15', 1)],
#  '$700.': [('15', 1)],
#  'nick': [('15', 1)],
#  "bollettieri's": [('15', 1)],
#  'tennis': [('15', 1)],
#  'pullout': [('15', 1)],
#  'and,': [('15', 1)],
#  '17-year-old': [('15', 1)],
#  'secured': [('15', 1)],
#  'straight': [('15', 1)],
#  'social': [('16', 2)],
#  'ics': [('16', 1)],
#  'focused': [('16', 1)],
#  'organizations': [('16', 1)],
#  'computerization.': [('16', 1)],
#  'technical': [('16', 1)],
#  'specialists': [('16', 1)],
#  'systems': [('16', 1)],
#  'use.': [('16', 1)],
#  'issues': [('16', 1)],
#  'medical': [('16', 1)],
#  'uses.': [('16', 1)],
#  'significant': [('16', 1)],
#  'phenomena,': [('16', 1)],
#  'informatics,': [('16', 1)],
#  'warrant': [('16', 1)],
#  'understanding.': [('16', 1)],
#  '1970s': [('16', 1)],
#  '1980s,': [('16', 1)],
#  'informat-': [('16', 1)],
#  'sites': [('16', 1)],
#  'gotten': [('16', 1)],
#  'era': [('16', 1)],
#  'internet,': [('16', 2)],
#  'access': [('16', 2), ('18', 1)],
#  'home,': [('16', 2)],
#  'communication': [('16', 1)],
#  'entertainment,': [('16', 1)],
#  'information,': [('16', 1)],
#  'personal': [('16', 1)],
#  'topics': [('16', 1)],
#  'emphasize.': [('16', 1)],
#  'part': [('16', 1)],
#  'lines': [('16', 1)],
#  'analysis': [('16', 1), ('18', 1)],
#  ...}

# %%
# search words

def search(a,b,c):
  words_list = list(a.lower().split(' '))
  words_p = sc.parallelize(words_list)
  words_filter = words_p.filter(lambda x: x not in c).collect()


  word_list = {}
  for i in words_filter:
    word_list[i] = b[i]

  joint_frequencies ={}
  for i in word_list.values():
    for x,y in i:
      if x not in joint_frequencies.keys():
        joint_frequencies[x] = y
      else:
        joint_frequencies[x]+=y

  freq = sorted(joint_frequencies.items(), key = lambda i: i[1], reverse = True)

  return {a : freq}

# %%
print(search(input('Please input words seperated by space: '),dict_words,stopwords_list))
# Out:
# Please input words seperated by space: many years
# {'many years': [('16', 2), ('08', 2), ('14', 2), ('18', 2), ('05', 1), ('07', 1), ('12', 1), ('09', 1), ('15', 1)]}
